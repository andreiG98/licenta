# %%
from google.colab import drive
drive.mount('/content/gdrive/')

# %cd 'gdrive/My Drive/licenta/car_model_classification/model'
# Out:
# Drive already mounted at /content/gdrive/; to attempt to forcibly remount, call drive.mount("/content/gdrive/", force_remount=True).
# /content/gdrive/My Drive/licenta/car_model_classification/model

# %%
from se_vgg import se_vgg19_bn

# %%
model = se_vgg19_bn(pretrained=True)

print(model)
# Out:
# SEVGG(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): SEModule(
#       (avg_pool): AdaptiveAvgPool2d(output_size=1)
#       (fc1): Conv2d(64, 4, kernel_size=(1, 1), stride=(1, 1))
#       (relu): ReLU(inplace=True)
#       (fc2): Conv2d(4, 64, kernel_size=(1, 1), stride=(1, 1))
#       (sigmoid): Sigmoid()
#     )
#     (4): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (5): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU(inplace=True)
#     (7): SEModule(
#       (avg_pool): AdaptiveAvgPool2d(output_size=1)
#       (fc1): Conv2d(64, 4, kernel_size=(1, 1), stride=(1, 1))
#       (relu): ReLU(inplace=True)
#       (fc2): Conv2d(4, 64, kernel_size=(1, 1), stride=(1, 1))
#       (sigmoid): Sigmoid()
#     )
# ...
